# %% [markdown]
# ### Exercício 1
#
# Crie um programa que leia a idade do usuário e classifique-o em:
# - Criança – 0 a 12 anos
# - Adolescente – 13 a 17 anos
# - Adulto – acima de 18 anos
#  -Se o usuário digitar um número negativo, mostrar a mensagem que a idade é inválida

# %%
# inserindo informações iniciais
nome = input('Digite seu nome:   ')
idade = int(input('Digite sua idade:    '))

# classificando o usuário
if idade < 0:
  print('A idade informada é inválida')
elif (idade >= 0) and (idade <= 12):
  print(f'{nome} é criança')
elif (idade >= 13) and (idade <= 17):
  print(f'{nome} é adolescente')
else:
  print(f'{nome} é adulto')
# Out:
# Digite seu nome:   Victor
# Digite sua idade:    15
# Victor é adolescente

# %% [markdown]
# ### Exercício 2
#
# Crie um programa que leia um número inteiro e apresenta as seguintes mensagens:
# - “O valor está na faixa permitida”, caso o valor esteja entre 1 e 9
# - “O valor está fora da faixa permitida”, caso o valor seja menor que 1 OU maior que 9

# %%
# definindo o valor
valor = int(input('Digite um valor: \n'))

# classificando o valor fornecido
if valor >= 1 and valor <= 9:
  print(f'O valor {valor} está na faixa permitida')
else:
  print(f'O valor {valor} está fora da faixa permitida')
# Out:
# Digite um valor:
# 75
# O valor 75 está fora da faixa permitida

# %% [markdown]
# ### Exercício 3
#
# Crie um programa que calcule a média de um aluno que cursou a disciplina de Estatística, a partir da leitura das notas M1, M2 e M3; passando por um cálculo da média aritmética. Após a média calculada, devemos anunciar se o aluno foi aprovado, reprovado ou pegou exame
# - Se a média estiver entre 0.0 e 4.0, o aluno está reprovado
# - Se a média estiver entre 4.1 e 6.0, o aluno pegou exame
# - Se a média for maior do que 6.0, o aluno está aprovado
# - Se o aluno pegou exame, deve ser lida a nota do exame. Se a nota do exame for maior do que 6.0, está aprovado, senão; está reprovado

# %%
# variaves a serem usadas
media = 0
nota = 0

# criando o programa para gerar a média
while(nota < 3):
  nota += 1
  media += float(input(f"Digite a nota {nota}\n"))
media /= nota
print(media)

# avaliando o resultado do aluno
if media >= 0 and media <= 4:
  print('O aluno está reprovado')
elif media > 4 and media <= 6:
  print('O aluno pegou exame')
  nota_exame = float(input("Digite a nota do exame \n"))
  if nota_exame > 6:
    print('O aluno está aprovado pelo exame')
  else:
    print('O aluno está reprovado pelo exame')
elif media > 6:
  print('O aluno está aprovado')
# Out:
# Digite a nota 1
# 4
# Digite a nota 2
# 8
# Digite a nota 3
# 1
# 4.333333333333333
# O aluno pegou exame
# Digite a nota do exame
# 6
# O aluno está reprovado pelo exame

# %% [markdown]
# ### Exercício 4
# Crie um programa que leia dois números reais e uma operação, e com isso imprima o resultado de acordo com a operação escolhida pelo usuário: adição, subtração, multiplicação e divisão.
# Caso seja informada operação inválida, mostrar na tela

# %%
# definindo as operacoes
def soma(numero_1, numero_2):
    print(numero_1 + numero_2)

def subtracao(numero_1, numero_2):
    print(numero_1 - numero_2)

def multiplicacao(numero_1, numero_2):
    print(numero_1 * numero_2)

def divisao(numero_1, numero_2):
    if numero_2 == 0:
        return "Essa é uma operação inválida"
    else:
        print(numero_1 / numero_2)

def calculadora():
    # inserindo informações necessarias
    operacao = input('''Digite a operação desejada:
    soma
    subtracao
    multiplicacao
    divisao\n''')

    numero_1 = float(input('Digite o primeiro valor: \n'))
    numero_2 = float(input('Digite o segundo valor: \n'))

    if operacao == 'soma':
        soma(numero_1, numero_2)
    elif operacao == 'subtracao':
        subtracao(numero_1, numero_2)
    elif operacao == 'multiplicacao':
        multiplicacao(numero_1, numero_2)
    elif operacao == 'divisao':
        divisao(numero_1, numero_2)
    else:
        print('Escolha uma operação válida')

calculadora()
# Out:
# Digite a operação desejada:
#     soma
#     subtracao
#     multiplicacao
#     divisao
# multiplicacao
# Digite o primeiro valor:
# 5
# Digite o segundo valor:
# 9
# 45.0
