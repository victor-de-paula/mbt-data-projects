# %% [markdown]
# <div>
# <p ><img  align="right" src="https://res.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco,dpr_1/aj29iemt0ogdyrdlksd4" height="160px"></p>
# </div>
#
# <br>
# <br>
#
# # **Aula 06 - Agrupamento e Ordenação**
#
# <br>
# <br>
#
# ___

# %% [markdown]
# **Importação da Biblioteca**

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Arquivos/ideb.csv')

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino anos_escolares  \
# 0  2011       PR       4110805    publica  fundamental   finais (6-9)
# 1  2019       PA       1506906  municipal  fundamental   finais (6-9)
# 2  2021       MS       5007307   estadual  fundamental   finais (6-9)
# 3  2021       RN       2410009  municipal  fundamental   finais (6-9)
# 4  2005       PR       4117305    publica  fundamental   finais (6-9)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            73.6              0.732192                 255.3
# 1            93.1              0.931595                 249.0
# 2             NaN                   NaN                   NaN
# 3             NaN                   NaN                   NaN
# 4            71.1              0.716839                 239.1
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       237.94                     4.887500   3.6       3.8
# 1                       264.36                     5.223000   4.9       5.2
# 2                          NaN                          NaN   NaN       4.8
# 3                          NaN                          NaN   NaN       4.8
# 4                       223.19                     4.372333   3.1       NaN

# %% [markdown]
# **groupby**
#
# Uma operação groupby envolve alguma combinação de dividir o objeto, aplicar uma função e combinar os resultados. Isso pode ser usado para agrupar grandes quantidades de dados e computar operações em grupos.

# %%
df_new = df.loc[:, ['sigla_uf', 'rede', 'ensino', 'ideb']]

# %%
df_new.head()
# Out:
#   sigla_uf       rede       ensino  ideb
# 0       PR    publica  fundamental   3.6
# 1       PA  municipal  fundamental   4.9
# 2       MS   estadual  fundamental   NaN
# 3       RN  municipal  fundamental   NaN
# 4       PR    publica  fundamental   3.1

# %%
df.groupby(['rede'])[['ideb']].mean()
# Out:
#                ideb
# rede
# estadual   4.268337
# federal    5.754545
# municipal  4.388722
# publica    4.316808

# %%
df.groupby(['rede', 'ensino'])[['ideb']].sum()
# Out:
#                           ideb
# rede      ensino
# estadual  fundamental   7878.4
#           medio         1234.5
# federal   fundamental     41.1
#           medio           85.5
# municipal fundamental   9938.5
#           medio           23.9
# publica   fundamental  12338.4
#           medio         1402.0

# %%
df.groupby(['rede', 'ensino'])[['ideb']].mean()
# Out:
#                            ideb
# rede      ensino
# estadual  fundamental  4.359934
#           medio        3.763720
# federal   fundamental  6.850000
#           medio        5.343750
# municipal fundamental  4.389797
#           medio        3.983333
# publica   fundamental  4.394017
#           medio        3.738667

# %%
df['rede'].value_counts()
# Out:
# publica      3885
# estadual     3139
# municipal    2919
# federal        57
# Name: rede, dtype: int64

# %%
df['ensino'].value_counts()
# Out:
# fundamental    8833
# medio          1167
# Name: ensino, dtype: int64

# %% [markdown]
# **sort_values**
#
# Classifique pelos valores ao longo de qualquer eixo.

# %%
df_new.head()
# Out:
#   sigla_uf       rede       ensino  ideb
# 0       PR    publica  fundamental   3.6
# 1       PA  municipal  fundamental   4.9
# 2       MS   estadual  fundamental   NaN
# 3       RN  municipal  fundamental   NaN
# 4       PR    publica  fundamental   3.1

# %%
df_new.sort_values(['ideb'], ascending=True, inplace=True)

# %%
df_new.head()
# Out:
#      sigla_uf       rede       ensino  ideb
# 5809       RN   estadual  fundamental   1.0
# 8901       RN   estadual  fundamental   1.0
# 8415       BA  municipal  fundamental   1.4
# 3338       AL  municipal  fundamental   1.5
# 951        RN  municipal  fundamental   1.6

# %%
df_new.sort_values(['ideb'], ascending=False, inplace=True)

# %%
df_new.head()
# Out:
#      sigla_uf       rede       ensino  ideb
# 4115       PR  municipal  fundamental   8.7
# 2582       CE  municipal  fundamental   8.5
# 8459       SP   estadual  fundamental   8.3
# 2995       PR    publica  fundamental   8.0
# 7760       PR  municipal  fundamental   7.9

# %%
df_new.sort_values(['ideb', 'rede'], ascending=False, inplace=True)

# %%
df_new.head()
# Out:
#      sigla_uf       rede       ensino  ideb
# 4115       PR  municipal  fundamental   8.7
# 2582       CE  municipal  fundamental   8.5
# 8459       SP   estadual  fundamental   8.3
# 2995       PR    publica  fundamental   8.0
# 7760       PR  municipal  fundamental   7.9
