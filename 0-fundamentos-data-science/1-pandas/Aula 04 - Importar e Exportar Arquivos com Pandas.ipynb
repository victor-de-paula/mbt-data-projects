# %% [markdown]
# <div>
# <p ><img  align="right" src="https://res.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco,dpr_1/aj29iemt0ogdyrdlksd4" height="160px"></p>
# </div>
#
# <br>
# <br>
#
# # **Aula 04 - Importar e Exportar Arquivos com Pandas**
# <br>
# <br>
#
# ___

# %% [markdown]
# Base utilizada: https://docs.google.com/spreadsheets/d/11MISuHS_37Bnj0wgfJQ0xGJ9D5Nx3VQU/edit?usp=sharing&ouid=117842070993131990987&rtpof=true&sd=true

# %% [markdown]
# **Importação da Biblioteca**

# %%
import pandas as pd

# %%
df = pd.read_csv('ideb.csv')

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino anos_escolares  \
# 0  2011       PR       4110805    publica  fundamental   finais (6-9)
# 1  2019       PA       1506906  municipal  fundamental   finais (6-9)
# 2  2021       MS       5007307   estadual  fundamental   finais (6-9)
# 3  2021       RN       2410009  municipal  fundamental   finais (6-9)
# 4  2005       PR       4117305    publica  fundamental   finais (6-9)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            73.6              0.732192                 255.3
# 1            93.1              0.931595                 249.0
# 2             NaN                   NaN                   NaN
# 3             NaN                   NaN                   NaN
# 4            71.1              0.716839                 239.1
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       237.94                     4.887500   3.6       3.8
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.dtypes
# Out:
# ano                              int64
# sigla_uf                        object
# id_municipio                     int64
# rede                            object
# ensino                          object
# anos_escolares                  object
# taxa_aprovacao                 float64
# indicador_rendimento           float64
# nota_saeb_matematica           float64
# nota_saeb_lingua_portuguesa    float64
# nota_saeb_media_padronizada    float64
# ideb                           float64
# projecao                       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano                          10000 non-null  int64
#  1   sigla_uf                     10000 non-null  object
#  2   id_municipio                 10000 non-null  int64
#  3   rede                         10000 non-null  object
#  4   ensino                       10000 non-null  object
#  5   anos_escolares               10000 non-null  object
#  6   taxa_aprovacao               7887 non-null   float64
#  7   indicador_rendimento         7887 non-null   float64
#  8   nota_saeb_matematica         6800 non-null   float64
#  9   nota_saeb_lingua_portuguesa  6800 non-null   float64
#  10  nota_saeb_media_padronizada  7610 non-null   float64
#  11  ideb                         7610 non-null   float64
# ...

# %%
df['rede'].value_counts()
# Out:
# publica      3885
# estadual     3139
# municipal    2919
# federal        57
# Name: rede, dtype: int64

# %% [markdown]
# **Importando Arquivos do Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Arquivos/ideb.csv')

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino anos_escolares  \
# 0  2011       PR       4110805    publica  fundamental   finais (6-9)
# 1  2019       PA       1506906  municipal  fundamental   finais (6-9)
# 2  2021       MS       5007307   estadual  fundamental   finais (6-9)
# 3  2021       RN       2410009  municipal  fundamental   finais (6-9)
# 4  2005       PR       4117305    publica  fundamental   finais (6-9)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            73.6              0.732192                 255.3
# 1            93.1              0.931595                 249.0
# 2             NaN                   NaN                   NaN
# 3             NaN                   NaN                   NaN
# 4            71.1              0.716839                 239.1
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       237.94                     4.887500   3.6       3.8
# ...

# %%
df['X'] = df['ano'] * 2

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino anos_escolares  \
# 0  2011       PR       4110805    publica  fundamental   finais (6-9)
# 1  2019       PA       1506906  municipal  fundamental   finais (6-9)
# 2  2021       MS       5007307   estadual  fundamental   finais (6-9)
# 3  2021       RN       2410009  municipal  fundamental   finais (6-9)
# 4  2005       PR       4117305    publica  fundamental   finais (6-9)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            73.6              0.732192                 255.3
# 1            93.1              0.931595                 249.0
# 2             NaN                   NaN                   NaN
# 3             NaN                   NaN                   NaN
# 4            71.1              0.716839                 239.1
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao  \
# 0                       237.94                     4.887500   3.6       3.8
# ...

# %% [markdown]
# **Exportando Arquivo no Drive**

# %%
df.to_csv('/content/drive/MyDrive/Arquivos/meu_arquivo.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/Arquivos/meu_arquivo.csv')

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino anos_escolares  \
# 0  2011       PR       4110805    publica  fundamental   finais (6-9)
# 1  2019       PA       1506906  municipal  fundamental   finais (6-9)
# 2  2021       MS       5007307   estadual  fundamental   finais (6-9)
# 3  2021       RN       2410009  municipal  fundamental   finais (6-9)
# 4  2005       PR       4117305    publica  fundamental   finais (6-9)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            73.6              0.732192                 255.3
# 1            93.1              0.931595                 249.0
# 2             NaN                   NaN                   NaN
# 3             NaN                   NaN                   NaN
# 4            71.1              0.716839                 239.1
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao  \
# 0                       237.94                     4.887500   3.6       3.8
# ...
