# %% [markdown]
# # **Exercícios Python**
# ___

# %% [markdown]
# *Exercício 1: Usando o comando print*
#
# Imprima a frase "Olá, mundo!" na tela.

# %%
print('Olá, mundo!')
# Out:
# Olá, mundo!

# %% [markdown]
# *Exercício 2: Usando f-string para Formatção*
#
# Crie um programa que solicite ao usuário seu nome e, em seguida, imprima uma mensagem de saudação com seu nome usando uma f-string.

# %%
nome = input("Qual o seu nome? ")
saudacao = f"\nOlá, {nome}. Prazer em conhecê-lo(a)!"
print(saudacao)
# Out:
# Qual o seu nome? Victor
#
# Olá, Victor. Prazer em conhecê-lo(a)!

# %% [markdown]
# *Exercício 3: Usando format() para Formatção*
#
# Crie um programa que solicite ao usuário seu nome e idade. Em seguida, imprima uma mensagem de boas-vindas com esses dados usando a função format()

# %%
nome = input('Qual o seu nome? ')
idade = int(input('E qual a sua idade? '))

boas_vindas = '\nOlá, {nome}! \nVi que você tem {idade} anos. \nMuito prazer em conhecê-lo(a).'.format(nome = nome, idade = idade)

print(boas_vindas)
# Out:
# Qual o seu nome? Victor
# E qual a sua idade? 25
#
# Olá, Victor!
# Vi que você tem 25 anos.
# Muito prazer em conhecê-lo(a).

# %% [markdown]
# *Exercício 4: Conversão de Tipos*
#
# Crie um programa que solicite ao usuário um número inteiro e, em seguida, multiplique esse número por 2 e imprima o resultado.

# %%
def multiplica_por_dois():
  numero = int(input('Digite um número inteiro: '))
  multiplicado = numero * 2
  return multiplicado

resultado = multiplica_por_dois()
print(f'O número passado, multiplicado por 2, é igual a {resultado}.')
# Out:
# Digite um número inteiro: 17
# O número passado, multiplicado por 2, é igual a 34.

# %% [markdown]
# *Exercício 5: Soma de Números*
#
# Crie um programa que solicite ao usuário dois números inteiros, some-os e imprima o resultado.

# %%
def soma_dois_numeros():
  numero1 = int(input("Digite um número inteiro: "))
  numero2 = int(input("Digite outro número inteiro: "))
  soma = numero1 + numero2
  return soma, numero1, numero2

resultado, numero1, numero2 = soma_dois_numeros()
print(f'A soma de {numero1} mais {numero2} é igual a {resultado}.')
# Out:
# Digite um número inteiro: 1545
# Digite outro número inteiro: 5874
# A soma de 1545 mais 5874 é igual a 7419.

# %% [markdown]
# *Exercício 6: Operadores Aritméticos*
#
# Crie um programa que solicite ao usuário dois números inteiros e, em seguida, realize as seguintes operações:
# - Some os números.
# - Subtraia o segundo número do primeiro.
# - Multiplique os números.

# %%
def operacoes_matematicas():
  numero1 = int(input("Digite um número inteiro: "))
  numero2 = int(input("Digite outro número inteiro: "))
  soma = numero1 + numero2
  subtracao = numero2 - numero1
  multiplicacao = numero1 * numero2
  return soma, subtracao, multiplicacao, numero1, numero2

soma, subtracao, multiplicacao, numero1, numero2 = operacoes_matematicas()
print(f'Para os números {numero1} e {numero2}, temos: \nSoma = {soma} \nSubtração = {subtracao} \nMultiplicação = {multiplicacao}')
# Out:
# Digite um número inteiro: 4
# Digite outro número inteiro: 8
# Para os números 4 e 8, temos:
# Soma = 12
# Subtração = 4
# Multiplicação = 32

# %% [markdown]
# *Exercício 7: Operadores de Comparação Lógica com Número de Referência*
#
# Crie um programa que solicite ao usuário um número inteiro.
# Peça ao usuário para inserir um número de referência.
# Em seguida, verifique e imprima se o número inserido pelo usuário é:
# - Igual ao número de referência.
# - Maior que o número de referência.
# - Menor que o número de referência.

# %%
def comparacao_logica():
  n_inteiro = int(input("Digite um número inteiro: "))
  n_referencia = int(input("Digite um número de referência: "))
  igual = n_inteiro == n_referencia
  maior = n_inteiro > n_referencia
  menor = n_inteiro < n_referencia
  return igual, maior, menor, n_inteiro, n_referencia

igual, maior, menor, n_inteiro, n_referencia = comparacao_logica()
print(f"O número inteiro {n_inteiro}, em comparação com o número de referência {n_referencia}, é: \nIgual: {igual} \nMaior: {maior} \nMenor: {menor}")
# Out:
# Digite um número inteiro: 16
# Digite um número de referência: 22
# O número inteiro 16, em comparação com o número de referência 22, é:
# Igual: False
# Maior: False
# Menor: True

# %% [markdown]
# *Exercício 8: Verificação de Divisibilidade*
#
# Crie um programa que solicita ao usuário um número e, em seguida, imprime mensagens indicando:
# - Se o número é divisível por 3.
# - Se o número é divisível por 4.
# - Se o número é divisível por 3 e por 4.
# - Se o número é divisível por 3 ou por 4.

# %%
def verifica_divisao():
    numero = int(input("Digite um número inteiro: "))

    divisivel_por_3 = numero % 3 == 0
    divisivel_por_4 = numero % 4 == 0

    print(f"O número {numero} é divisível por 3: {divisivel_por_3}")
    print(f"O número {numero} é divisível por 4: {divisivel_por_4}")

    if divisivel_por_3 and divisivel_por_4:
        print(f"O número {numero} é divisível por 3 e por 4: True")
    else:
        print(f"O número {numero} é divisível por 3 e por 4: False")

    if divisivel_por_3 or divisivel_por_4:
        print(f"O número {numero} é divisível por 3 ou por 4: True")
    else:
        print(f"O número {numero} é divisível por 3 ou por 4: False")

verifica_divisao()
# Out:
# Digite um número inteiro: 320
# O número 320 é divisível por 3: False
# O número 320 é divisível por 4: True
# O número 320 é divisível por 3 e por 4: False
# O número 320 é divisível por 3 ou por 4: True

# %% [markdown]
# *Exercício 9: Verificação de Paridade*
#
# Crie um programa que solicita ao usuário um número inteiro e, em seguida, imprime se o número é par ou ímpar.

# %%
def verifica_paridade():
  numero = int(input('Digite um número inteiro: '))

  divisao_por_2 = numero % 2 == 0

  if divisao_por_2:
    print(f'O número inteiro {numero} é par.')
  else:
    print(f'O número inteiro {numero} é ímpar.')

verifica_paridade()
# Out:
# Digite um número inteiro: 15
# O número inteiro 15 é ímpar.

# %% [markdown]
# *Exercício 10: Verificação de Maioridade*
#
# Crie um programa que solicita ao usuário sua idade e, em seguida, verifica se a pessoa é maior de idade (idade maior ou igual a 18 anos).

# %%
def verifica_maioridade():
  nome = input('Digite o seu nome completo: ').upper()
  idade = int(input('Digite a sua idade: '))

  if idade >= 18:
    print(f'\n{nome} tem {idade} anos e é maior de idade.')
  elif 0 <= idade < 18:
    print(f'\n{nome} tem {idade} anos e é menor de idade.')
  else:
    print(f'\nPor favor, reexecute o programa novamente e informe uma idade válida.')

verifica_maioridade()
# Out:
# Digite o seu nome completo: Victor de Paula Silva
# Digite a sua idade: 25
#
# VICTOR DE PAULA SILVA tem 25 anos e é maior de idade.

# %% [markdown]
# *Exercício 11: Verificação de Número Positivo, Negativo ou Zero*
#
# Crie um programa que solicita ao usuário um número e, em seguida, verifica se o número é positivo, negativo ou igual a zero.

# %%
def verifica_numero_sinal():
  try:
    numero = int(input('Digite um número inteiro: '))
  except ValueError:
    print('\nDigite um número válido.')
    return

  if numero > 0:
    print(f'\nO número inteiro {numero} é Positivo.')
  elif numero < 0:
    print(f'\nO número inteiro {numero} é Negativo.')
  else:
    print(f'\nO número é igual a 0.')

verifica_numero_sinal()
# Out:
# Digite um número inteiro: 10.5
#
# Digite um número válido.

# %% [markdown]
# *Exercício 12: Verificação de Número Maior*
#
# Crie um programa que solicita ao usuário dois números inteiros e, em seguida, verifica e imprime qual deles é o maior.

# %%
def verifica_numero_maior():
  try:
    numero1 = int(input("Digite um número inteiro: "))
  except ValueError:
    print('\nPor favor, reexecute o programa novamente e informe um número válido.')
    return
  try:
    numero2 = int(input("Digite outro número inteiro: "))
  except ValueError:
    print('\nPor favor, reexecute o programa novamente e informe um número válido.')
    return

  if numero1 > numero2:
    print(f'\nO número {numero1} é maior do que o número {numero2}.')
  elif numero1 < numero2:
    print(f'\nO número {numero2} é maior do que o número {numero1}.')
  else:
    print(f'\nOs dois números {numero1} são iguais.')

verifica_numero_maior()
# Out:
# Digite um número inteiro: 20
# Digite outro número inteiro: 15
#
# O número 20 é maior do que o número 15.

# %% [markdown]
# *Exercício 13: Acesso a Elementos de uma Lista*
#
# Crie uma lista de nomes de frutas: "maçã", "banana", "laranja", "uva", "morango".
# Use a indexação para acessar e imprimir o terceiro elemento da lista.

# %%
frutas = ["maçã", "banana", "laranja", "uva", "morango"]

print(f'A lista frutas têm estes elementos: {frutas}.')
print(f'O terceiro elemento da lista frutas é {frutas[2]}.')
# Out:
# A lista frutas têm estes elementos: ['maçã', 'banana', 'laranja', 'uva', 'morango'].
# O terceiro elemento da lista frutas é laranja.

# %% [markdown]
# *Exercício 14: Modificação de Elementos de uma Lista*
#
# Crie uma lista de números inteiros de 1 a 5.
# Use a indexação para modificar o terceiro elemento da lista para 10.
# Imprima a lista resultante

# %%
numeros_inteiros = [1, 2, 3, 4, 5]
numeros_inteiros[2] = 10

print(f'A nova lista de números inteiros, com alteração do 3º elemento, é: {numeros_inteiros}.')0
# Out:
# A nova lista de números inteiros, com alteração do 3º elemento, é: [1, 2, 10, 4, 5].

# %% [markdown]
# *Exercício 15: Extração de Partes de uma Lista*
#
# Crie uma lista de cores: "vermelho", "verde", "azul", "amarelo", "roxo".
# Use a indexação para criar uma nova lista que contenha apenas as três primeiras cores.
# Imprima a nova lista.

# %%
cores = ["vermelho", "verde", "azul", "amarelo", "roxo"]
primeiras_3_cores = cores[0:3]

print(f'A lista cores original contêm estes elementos: {cores}.')
print(f'Já a nova lista, que contêm apenas as 3 primeiras cores da original, é: {primeiras_3_cores}.')
# Out:
# A lista cores original contêm estes elementos: ['vermelho', 'verde', 'azul', 'amarelo', 'roxo'].
# Já a nova lista, que contêm apenas as 3 primeiras cores da original, é: ['vermelho', 'verde', 'azul'].

# %% [markdown]
# *Exercício 16: Concatenação de Listas*
#
# Crie duas listas: uma com números de 1 a 3 e outra com números de 4 a 6.
# Use a indexação para criar uma terceira lista que contenha a concatenação das duas listas.
# Imprima a terceira lista.

# %%
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]
lista3 = lista1 + lista2

print(f'A lista 1 é: {lista1} \nJá a lista 2 é: {lista2} \nA concatenção delas resulta em: {lista3}')
# Out:
# A lista 1 é: [1, 2, 3]
# Já a lista 2 é: [4, 5, 6]
# A concatenção delas resulta em: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# *Exercício 17: Criação e Acesso a Elementos de uma Tupla*
#
# Crie uma tupla chamada meses com os nomes dos meses do ano.
# Acesse e imprima o terceiro mês da tupla.

# %%
meses = ('Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro')

print(f'A tupla meses contêm estes elementos: {meses}.')
print(f'O terceiro mês da tupla é: {meses[2]}.')
# Out:
# A tupla meses contêm estes elementos: ('Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro').
# O terceiro mês da tupla é: Março.

# %% [markdown]
# *Exercício 18: Criação e Acesso a Elementos de uma Tupla*
#
# Crie uma tupla com o nome e a idade de uma pessoa e escreva na tela uma saudação com as informações contidas na tupla

# %%
# Out:
# Olá, Nathaline! Você tem 30 anos.

# %% [markdown]
# *Exercício 19: Impressão de Números Pares*
#
# Crie um loop for que imprime todos os números pares de 1 a 10.

# %% [markdown]
# *Exercício 20: Soma de Números Ímpares*
#
# Crie um loop for que calcula a soma de todos os números ímpares de 1 a 20 e imprime o resultado.

# %% [markdown]
# *Exercício 21: Impressão de Nomes*
#
# Crie uma lista de nomes de frutas: "maçã", "banana", "laranja", "uva", "morango".
# Use um loop for para imprimir cada nome de fruta da lista.

# %% [markdown]
# *Exercício 22: Contagem de Vogais*
#
# Crie uma string contendo uma frase de sua escolha.
# Use um loop for para contar e imprimir o número de vogais (a, e, i, o, u) na frase.

# %% [markdown]
# *Exercício 23: Tabuada de Multiplicação*
#
# Crie um loop for que calcula e imprime a tabuada de multiplicação de um número inteiro fornecido pelo usuário.

# %% [markdown]
# *Exercício 24: Contagem Crescente*
#
# Crie um loop while que imprime os números de 1 a 5 em ordem crescente

# %% [markdown]
# *Exercício 25: Contagem Regressiva*
#
# Crie um loop while que imprime os números de 10 a 1 em ordem decrescente.

# %% [markdown]
# *Exercício 26: Soma de Números Pares*
#
# Crie um loop while que calcula a soma de todos os números pares de 2 a 20 e imprime o resultado.

# %% [markdown]
# *Exercício 27: Jogo de Adivinhação*
#
# Crie um programa que gera um número aleatório entre 1 e 100.
# Peça ao usuário para adivinhar o número e informe se é maior ou menor.
# Continue pedindo palpites até que o usuário adivinhe o número.

# %% [markdown]
# *Exercício 28: Contagem de Fatoriais*
#
# Crie um programa que calcula e imprime os fatoriais dos números de 1 a 5 usando um loop while.

# %% [markdown]
# *Exercício 29: Vamos criar uma calculadora (simples) com as operações soma, subtração, multiplicação, divisão.*
#
# Dica: crie funções para tarefas específicas como, por exemplo, uma função `soma(a,b)`, uma função `subtracao(a,b)`, ... e depois use estas funções para criar a função `calculadora()`.
#
# Lembre-se de que não se pode dividir por zero.

# %%
# Out:
# Escolha o número da operação a ser realizada:
#     1) soma
#     2) subtração
#     3) multiplicação
#     4) divisão
#     5) encerrar calculadora
# 1
# Digite o primeiro valor: 2
# Digite o segundo valor: 3
#
# Escolhida a operação de soma
# 5.0

# %% [markdown]
# *Exercício 30: Em um curso da Sirius temos alunos dos mais variados perfis, tendo diferentes faixas etárias, morando em diferentes estados do Brasil e que tiraram diferentes notas. Essas informações estão em diferentes listas, uma somente com os nomes, outras somente com as notas, outra com a idades e outro com os estados de residência.*
#
# Com base nisso crie funções que ajudem a responder as perguntas considerando os dados a seguir.

# %% [markdown]
# 1) Crie uma função que seleciona o nome de todas as pessoas que residem em um determinado estado. Por exemplo, a função `alunos_por_estado(nomes, estados, 'SP')` deve retornar todos os nomes dos alunos que moram em São Paulo.

# %%
# Out:
# (['José', 'Fernando', 'Guilherme'], ['SP', 'SP', 'SP'])

# %% [markdown]
# 2) Crie uma função que calcula quantas pessoas foram aprovadas por estado, considerando média 6. Por exemplo, a função `quant_aprov_estado(estados, notas, 'SP')` deve retornar quantos alunos foram aprovados no estado de São Paulo.

# %%
# Out:
# Há 2 aprovados no estado SP

# %% [markdown]
# 3) Crie uma função que calcula quantos alunos há por estado. Por exemplo, a função `alunos_por_estado(estados)` deve retornar uma mensagem dizendo quantos alunos há em cada estado.

# %%
# Out:
# No estado SC há 1 alunos
# No estado RO há 1 alunos
# No estado BA há 1 alunos
# No estado MS há 1 alunos
# No estado SP há 3 alunos
# No estado PB há 1 alunos
# No estado PE há 1 alunos
# No estado MG há 8 alunos
# No estado RR há 1 alunos
# No estado AM há 2 alunos
# No estado PR há 1 alunos
# No estado CE há 1 alunos
# No estado PA há 1 alunos
# No estado PI há 1 alunos
# No estado SE há 1 alunos
# No estado RJ há 1 alunos
# No estado ES há 1 alunos

# %% [markdown]
# 4) Crie uma função que calcula a média das notas dos alunos de um determinado estado. Por exemplo, a função `media_por_estado(notas, estados, 'SP')` deve retornar a média das notas do alunos (com duas casas decimais) do estado de São Paulo.

# %%
# Out:
# A média das notas dos alunos do estado SP foi de 5.67

# %% [markdown]
# 5) Crie uma função que calcula a média das idades dos alunos aprovados (considerando media 6) de um determinado estado. Por exemplo, a função `media_idade_aprov_por_estado(notas, estados, idades, 'SP')` deve retornar a média das idades do alunos (com duas casas decimais) aprovados que residem no estado de São Paulo.

# %%
# Out:
# A média de idade dos alunos aprovados do estado de SP é 36.5
